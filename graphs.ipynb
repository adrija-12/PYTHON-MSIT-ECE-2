# %%
# Out:
# [75 35 38 76 23 60 63 10 18 67] <class 'numpy.ndarray'> 10
# [36 32 66 49 30 43 60 32 46 59] <class 'numpy.ndarray'> 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 15
#      13         plt.ylabel("Students-> ")
#      14         plt.show()
# ---> 15 Graph.RandomArrayGraph()
#
# Cell In[16], line 9, in Graph.RandomArrayGraph()
#       7 print(x_axis,type(x_axis),len(x_axis))
#       8 print(y_axis,type(y_axis),len(y_axis))
# ----> 9 plt.plot(x_axis,marker="o",mfc="red",mec="orange",colour="blue")
#      10 plt.plot(y_axis,marker="o",mfc="purple",mec="red",color="violet")
#      11 plt.grid(color="green")
#
# File c:\Users\adrij\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
class Graph:
    def RandomArrayGraph():
        x_axis=np.random.randint(10,90,12)
        y_axis=np.random.randint(50,120,12)
        # x_axis=np.array_split(x_axis,2)
        # y_axis=np.array_split(y_axis,2)
        print(x_axis,type(x_axis),len(x_axis))
        print(y_axis,type(y_axis),len(y_axis))
        # plt.plot(x_axis,y_axis,marker="o",mfc="red",mec="red",color="blue")
        plt.plot(x_axis,marker="o",mfc="red",mec="red",color="blue")
        plt.plot(y_axis,marker="o",mfc="red",mec="red",color="yellow")
        plt.grid(color="green")
        plt.xlabel("Stocks")
        plt.ylabel("Share Price")
        plt.title("Stock Market")
        plt.show()
Graph.RandomArrayGraph()
# Out:
# [47 13 12 89 44 84 12 89 57 20 70 43] <class 'numpy.ndarray'> 12
# [116  89  97 109 100  83  51  78 100  93  54  58] <class 'numpy.ndarray'> 12
